# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: GROUP 1
# * Student pace: part time
# * Scheduled project review date/time: 4/1/2024
# * Instructor name: SAMWEL JANE
# * Blog post URL:

# %%
# Your code here - remember to use markdown cells for comments as well!

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
house_data=pd.read_csv(r"C:\Users\OTIENO BAKER OYUGI\Desktop\dsc-phase-2-project-v2-3\data\kc_house_data.csv")

# %%
house_data.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors waterfront  view  ...          grade sqft_above  \
# 0      5650     1.0        NaN  NONE  ...      7 Average       1180
# 1      7242     2.0         NO  NONE  ...      7 Average       2170
# 2     10000     1.0         NO  NONE  ...  6 Low Average        770
# 3      5000     1.0         NO  NONE  ...      7 Average       1050
# 4      8080     1.0         NO  NONE  ...         8 Good       1680
#
#    sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
house_data.sample(10)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 4495   2767603931   8/18/2014   469000.0         3       3.25         1370
# 20622   301400800  10/16/2014   261000.0         3       2.25         1584
# 748     579003610   2/24/2015   517500.0         3       1.50         1430
# 5870   2787720170   9/29/2014   395000.0         4       2.50         2130
# 1538   5253300397    4/9/2015   415000.0         3       1.50         1510
# 11064  4053200566  10/20/2014   425000.0         4       2.25         3680
# 9671   8857640710   8/20/2014   479000.0         4       2.50         2590
# 5833   4345000050   6/30/2014   245000.0         3       2.75         1300
# 5555    424069088    9/4/2014   406430.0         3       2.00         1380
# 12443  3303960060   6/19/2014  1070000.0         5       3.50         3990
#
#        sqft_lot  floors waterfront  view  ...         grade sqft_above  \
# ...

# %%
# check for missing data in the house data

print(house_data.isnull().sum())
# Out:
# id                  0
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2376
# view               63
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3842
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %%
#SHAPE OF DATASET
house_data.shape
# Out:
# (21597, 21)

# %%
# price-dependent
# bedrooms, sqft_living, floors, view,condition,zipcode,yr_built,sqft_above, lat, long-independent

# %%
#dropping rows with null values
clean_house_data= house_data.dropna()
print(clean_house_data.isnull().sum())
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
#checking for duplicate rows
house_data_duplicate=(house_data.duplicated().sum())
house_data_duplicate
# Out:
# 0
